# %%
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
train_df = pd.read_csv(Path('Resources/2019loans.csv'))
test_df = pd.read_csv(Path('Resources/2020Q1loans.csv'))

# %%
#review train_df
train_df.head()
# Out:
#    Unnamed: 0   index  loan_amnt  int_rate  installment home_ownership  \
# 0       57107   57107    13375.0    0.1797       483.34       MORTGAGE
# 1      141451  141451    21000.0    0.1308       478.68       MORTGAGE
# 2      321143  321143    20000.0    0.1240       448.95       MORTGAGE
# 3       11778   11778     3000.0    0.1240       100.22           RENT
# 4      169382  169382    30000.0    0.1612      1056.49       MORTGAGE
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    223000.0        Not Verified    low_risk          n  ...           100.0
# 1    123000.0     Source Verified    low_risk          n  ...            85.0
# 2    197000.0     Source Verified    low_risk          n  ...            85.7
# 3     45000.0        Not Verified    low_risk          n  ...           100.0
# 4    133000.0     Source Verified    low_risk          n  ...           100.0
#
# ...

# %%
#review test_df
test_df.head()
# Out:
#    Unnamed: 0  index  loan_amnt  int_rate  installment home_ownership  \
# 0       67991  67991    40000.0    0.0819       814.70       MORTGAGE
# 1       25429  25429     6000.0    0.1524       208.70           RENT
# 2       38496  38496     3600.0    0.1695       128.27           RENT
# 3       19667  19667    20000.0    0.1524       478.33           RENT
# 4       37505  37505     3600.0    0.1240       120.27           RENT
#
#    annual_inc verification_status loan_status pymnt_plan  ...  pct_tl_nvr_dlq  \
# 0    140000.0        Not Verified    low_risk          n  ...            97.7
# 1     55000.0        Not Verified    low_risk          n  ...            66.7
# 2     42000.0        Not Verified    low_risk          n  ...           100.0
# 3    100000.0        Not Verified    low_risk          n  ...           100.0
# 4     50000.0        Not Verified    low_risk          n  ...           100.0
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# ...

# %%
# Convert categorical data to numeric and separate target feature for training data
#convert data using get.dummies
#Drop the taget column and any unneeded columns
X = train_df.drop(['Unnamed: 0', 'loan_status'], axis=1)
X
# Out:
#         index  loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0       57107    13375.0    0.1797       483.34       MORTGAGE    223000.0
# 1      141451    21000.0    0.1308       478.68       MORTGAGE    123000.0
# 2      321143    20000.0    0.1240       448.95       MORTGAGE    197000.0
# 3       11778     3000.0    0.1240       100.22           RENT     45000.0
# 4      169382    30000.0    0.1612      1056.49       MORTGAGE    133000.0
# ...       ...        ...       ...          ...            ...         ...
# 12175  354912    19975.0    0.2565       801.09           RENT     28000.0
# 12176  354944    15000.0    0.1774       540.34           RENT     50000.0
# 12177  354973     3600.0    0.1862       131.28           RENT     60000.0
# 12178  355002    15000.0    0.0881       475.68       MORTGAGE     62000.0
# 12179  355307    15000.0    0.1774       540.34           RENT     54080.0
#
# ...

# %%
#convert data using get.dummies
X_train = pd.get_dummies(X)
print(X_train.columns)
X_train.head()
# Out:
# Index(['index', 'loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
# Converting output labels to 0 and 1 using LabelEncoder
y_train = LabelEncoder().fit_transform(train_df['loan_status'])
y_train
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %%
# Convert categorical data to numeric and separate target feature for testing data
X = test_df.drop(['Unnamed: 0', 'loan_status'], axis=1)

X
# Out:
#       index  loan_amnt  int_rate  installment home_ownership  annual_inc  \
# 0     67991    40000.0    0.0819       814.70       MORTGAGE    140000.0
# 1     25429     6000.0    0.1524       208.70           RENT     55000.0
# 2     38496     3600.0    0.1695       128.27           RENT     42000.0
# 3     19667    20000.0    0.1524       478.33           RENT    100000.0
# 4     37505     3600.0    0.1240       120.27           RENT     50000.0
# ...     ...        ...       ...          ...            ...         ...
# 4697  77282    30000.0    0.1240       673.42           RENT    140480.0
# 4698  77291    24000.0    0.0756       747.22           RENT     50000.0
# 4699  77292    10000.0    0.2305       387.36           RENT     33000.0
# 4700  77297     8000.0    0.1862       205.86           RENT     38000.0
# 4701  77304    30000.0    0.2055      1123.34           RENT    180000.0
#
#      verification_status pymnt_plan    dti  delinq_2yrs  ...  pct_tl_nvr_dlq  \
# ...

# %%
#convert data using get.dummies
X_test = pd.get_dummies(X)
print(X_test.columns)
X_test.head()
# Out:
# Index(['index', 'loan_amnt', 'int_rate', 'installment', 'annual_inc', 'dti',
#        'delinq_2yrs', 'inq_last_6mths', 'open_acc', 'pub_rec', 'revol_bal',
#        'total_acc', 'out_prncp', 'out_prncp_inv', 'total_pymnt',
#        'total_pymnt_inv', 'total_rec_prncp', 'total_rec_int',
#        'total_rec_late_fee', 'recoveries', 'collection_recovery_fee',
#        'last_pymnt_amnt', 'collections_12_mths_ex_med', 'policy_code',
#        'acc_now_delinq', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m',
#        'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il',
#        'total_bal_il', 'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc',
#        'all_util', 'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'chargeoff_within_12_mths', 'delinq_amnt', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
# ...

# %%
#Find missing test column
set(X_train.columns) - set(X_test.columns)
# Out:
# {'debt_settlement_flag_Y'}

# %%
# add missing dummy variables to testing set
X_test["debt_settlement_flag_Y"] = 0

X_test.head()
# Out:
#    index  loan_amnt  int_rate  installment  annual_inc    dti  delinq_2yrs  \
# 0  67991    40000.0    0.0819       814.70    140000.0  19.75          0.0
# 1  25429     6000.0    0.1524       208.70     55000.0  11.52          2.0
# 2  38496     3600.0    0.1695       128.27     42000.0   6.74          0.0
# 3  19667    20000.0    0.1524       478.33    100000.0  12.13          0.0
# 4  37505     3600.0    0.1240       120.27     50000.0  16.08          0.0
#
#    inq_last_6mths  open_acc  pub_rec  ...  verification_status_Verified  \
# 0             1.0      18.0      0.0  ...                             0
# 1             0.0       8.0      0.0  ...                             0
# 2             0.0       6.0      0.0  ...                             0
# 3             2.0       7.0      0.0  ...                             0
# 4             3.0       6.0      0.0  ...                             0
#
#    pymnt_plan_n  initial_list_status_f  initial_list_status_w  \
# ...

# %%
# Converting output labels to 0 and 1 using LabelEncoder
y_test = LabelEncoder().fit_transform(test_df['loan_status'])
y_test
# Out:
# array([1, 1, 1, ..., 0, 0, 0])

# %% [markdown]
# # Model Prediction
# My prediction is that the Random Forest Classifier model will perform better. I believe this will be true for the following reasons:
#  - There are a number of categorical columns in the dataset and a Random Forest Classifier may perform better
#  - There are a number of variables in the dataset and a Random Forest Classifier may perform better and capture feature patterns
#  - With Random Forest Classifier you could also feature selection to select only the relevant values in the dataset

# %%
# Train the Logistic Regression model on the unscaled data and print the model score
from sklearn.linear_model import LogisticRegression

classifier.fit(X_train,y_train)
print("Testing Score:", classifier.score(X_test, y_test))
print("Training Score:", classifier.score(X_train, y_train))
# Out:
# Testing Score: 0.5691195236069757
# Training Score: 0.7071428571428572

# %%
# Train a Random Forest Classifier model and print the model score
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=13, n_estimators=300).fit(X_train, y_train)
print(f'Testing Score: {clf.score(X_test, y_test)}')
print(f'Training Score: {clf.score(X_train, y_train)}')
# Out:
# Testing Score: 0.6897065078689919
# Training Score: 1.0

# %% [markdown]
# # Impact of Scaling
# My assumption is that scaling the data will improve the accuracy and performance of both models for the following reasons:
# - Reducing the magnitude of outliers or large values that can impact the accuracy of the model due the large size
# - There is a large range of values in the dataset. The machine learning algorithm does not know what the number represents and could make erroneous assumptions if not scaled.

# %%
# Scale the data
scaler = StandardScaler()
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
# Train the Logistic Regression model on the scaled data and print the model score
classifiers = LogisticRegression(solver="liblinear")

classifiers.fit(X_train_scaled, y_train)
print("Testing Score:", classifiers.score(X_test_scaled, y_test))
print("Training Score:", classifiers.score(X_train_scaled, y_train))
# Out:
# Testing Score: 0.719906422798809
# Training Score: 0.7126436781609196

# %%
# Train a Random Forest Classifier model on the scaled data and print the model score
clfs = RandomForestClassifier(random_state=1, n_estimators=300).fit(X_train_scaled, y_train)
print(f'Testing Score: {clfs.score(X_test_scaled, y_test)}')
print(f'Training Score: {clfs.score(X_train_scaled, y_train)}')
# Out:
# Testing Score: 0.6573798383666525
# Training Score: 1.0

# %% [markdown]
# # Model Comparisons
#
# ## Performance
# Prior to scaling, the models perform similarly with an edge to Random Forest. With Random Forest the accuracy is at 65% for the testing score and is 100% for the training score, which raises concerns of over-fitting.
#
# ## Scaling Improvements
# Surprisingly, scaling the data had an impact on the Testing Score of the Logistic Regression model but it did not seem to have much of an impact on the Random Forest Classifier. Based on Google research, Random Forest does not necessarily need scaling since the nature of the model does not present the numerical precision issues found with Logistic Regression.
#
# ## Final Thoughts
# I am going to change my position on the models and give the Logistic Regression a slight edge over Random Forest. After scaling the model performs better than Random Forest with a testing score of 72 % over the Random Forest testing score of 66%. Random Forest has a perfect training score, 100%, but I have concerns with over-fitting. Perhaps if feature selection was applied the chances of over-fitting could be reduced.
